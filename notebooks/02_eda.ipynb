# %%
import pandas as pd

df = pd.read_parquet("../data/houses.parquet")

df.head()
# Out:
#    LotArea  GrLivArea  GarageArea  OverallQual  OverallCond  YearBuilt  \
# 0     9270       1969          63            3            7       1984
# 1     2860       3396          87            9            1       2012
# 2     7390        892          32            5            6       1966
# 3     7191        508          71            5            1       1977
# 4    13964       1112         555            7            8       1986
#
#    YearRemodAdd  TotalBsmtSF  FullBath  HalfBath  ...  MSZoning  BldgType  \
# 0          1976         1583         1         1  ...        RM    2fmCon
# 1          1956         1501         1         0  ...        RH    2fmCon
# 2          2009         1005         1         0  ...        FV    2fmCon
# 3          1961          883         3         0  ...        RM    Duplex
# 4          1956         1083         2         0  ...        RH    2fmCon
#
#    HouseStyle KitchenQual ExterQual Foundation CentralAir PavedDrive  \
# 0      1.5Fin          Gd        Ex      PConc          Y          N
# 1      1Story          Gd        TA     BrkTil          Y          N
# 2      1.5Fin          Gd        Gd     CBlock          Y          N
# 3      1Story          Gd        TA      PConc          Y          Y
# 4      1.5Fin          TA        Ex      PConc          N          N
#
#   HeatingQC SalePrice
# 0        TA    354878
# 1        Gd    630152
# 2        Gd    256242
# 3        Ex    208098
# 4        Ex    286368
#
# [5 rows x 24 columns]

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotArea       25000 non-null  int64
#  1   GrLivArea     25000 non-null  int64
#  2   GarageArea    25000 non-null  int64
#  3   OverallQual   25000 non-null  int64
#  4   OverallCond   25000 non-null  int64
#  5   YearBuilt     25000 non-null  int64
#  6   YearRemodAdd  25000 non-null  int64
#  7   TotalBsmtSF   25000 non-null  int64
#  8   FullBath      25000 non-null  int64
#  9   HalfBath      25000 non-null  int64
#  10  TotRmsAbvGrd  25000 non-null  int64
#  11  Fireplaces    25000 non-null  int64
#  12  GarageCars    25000 non-null  int64
#  13  Neighborhood  25000 non-null  category
#  14  MSZoning      25000 non-null  category
#  15  BldgType      25000 non-null  object
#  16  HouseStyle    25000 non-null  object
#  17  KitchenQual   25000 non-null  object
#  18  ExterQual     25000 non-null  object
#  19  Foundation    25000 non-null  object
#  20  CentralAir    25000 non-null  object
#  21  PavedDrive    25000 non-null  object
#  22  HeatingQC     25000 non-null  object
#  23  SalePrice     25000 non-null  int64
# dtypes: category(2), int64(14), object(8)
# memory usage: 4.2+ MB
#             LotArea     GrLivArea    GarageArea   OverallQual   OverallCond  \
# count  25000.000000  25000.000000  25000.000000  25000.000000  25000.000000
# mean    8476.822400   2260.520800    498.715280      5.008640      4.494480
# std     3755.136646   1011.192463    288.759262      2.584777      2.297934
# min     2000.000000    500.000000      0.000000      1.000000      1.000000
# 25%     5216.750000   1390.000000    249.000000      3.000000      2.000000
# 50%     8460.500000   2264.000000    498.000000      5.000000      5.000000
# 75%    11742.250000   3134.000000    750.000000      7.000000      6.000000
# max    14999.000000   3999.000000    999.000000      9.000000      8.000000
#
#           YearBuilt  YearRemodAdd  TotalBsmtSF      FullBath      HalfBath  \
# count  25000.000000  25000.000000  25000.00000  25000.000000  25000.000000
# mean    1985.554200   1985.469080   1004.34116      1.999600      0.506680
# std       20.786567     20.839077    576.13498      0.814485      0.499965
# min     1950.000000   1950.000000      0.00000      1.000000      0.000000
# 25%     1967.000000   1967.000000    511.00000      1.000000      0.000000
# 50%     1986.000000   1985.000000   1002.00000      2.000000      1.000000
# 75%     2004.000000   2004.000000   1504.00000      3.000000      1.000000
# max     2021.000000   2021.000000   1999.00000      3.000000      1.000000
#
#        TotRmsAbvGrd    Fireplaces   GarageCars      SalePrice
# count  25000.000000  25000.000000  25000.00000   25000.000000
# mean       6.992520      1.004640      1.49820  408683.517920
# std        2.573295      0.820393      1.11877  131241.257695
# min        3.000000      0.000000      0.00000   74767.000000
# 25%        5.000000      0.000000      0.00000  303562.250000
# 50%        7.000000      1.000000      1.00000  409752.500000
# 75%        9.000000      2.000000      3.00000  514306.750000
# max       11.000000      2.000000      3.00000  739790.000000

# %%
df.isnull().sum()
# Out:
# LotArea         0
# GrLivArea       0
# GarageArea      0
# OverallQual     0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# TotalBsmtSF     0
# FullBath        0
# HalfBath        0
# TotRmsAbvGrd    0
# Fireplaces      0
# GarageCars      0
# Neighborhood    0
# MSZoning        0
# BldgType        0
# HouseStyle      0
# KitchenQual     0
# ExterQual       0
# Foundation      0
# CentralAir      0
# PavedDrive      0
# HeatingQC       0
# SalePrice       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

df["SalePrice"].hist(bins=50)
plt.title("Sale Price Distribution")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.scatterplot(x=df["GrLivArea"], y=df["SalePrice"])
plt.show()

sns.scatterplot(x=df["OverallQual"], y=df["SalePrice"])
plt.show()

# %%
sns.boxplot(x="Neighborhood", y="SalePrice", data=df)
plt.xticks(rotation=45)
plt.show()
